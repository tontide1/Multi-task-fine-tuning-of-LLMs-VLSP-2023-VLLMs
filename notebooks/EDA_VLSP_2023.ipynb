# %% [markdown]
# # vlsp-2023-vllm/lambada_vi

# %%
import pandas as pd

splits = {'test': 'data/test-00000-of-00001-0f570d0544259679.parquet', 'validation': 'data/validation-00000-of-00001-07192d6d50b20f30.parquet'}
df_lambada_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/lambada_vi/" + splits["test"])
df_lambada_val = pd.read_parquet("hf://datasets/vlsp-2023-vllm/lambada_vi/" + splits["validation"])

# %%
df_lambada_test.head(5)
# Out:
#                                                 text  \
# 0  Lâm nghiệp hay Vào rừng! ~ Chuyện vặt mỗi ngày...
# 1  Ngày 1 tháng 1 năm 1962, một phần của Herøy tr...
# 2  Sau hai cuộc chiến tranh Balkan vào năm 1912 v...
# 3  Nguỵ lược () là một sử liệu Trung Quốc do Ngư ...
# 4  Phần phía trước của tàu vũ trụ có chứa một thi...
#
#                                              context target_word  \
# 0  Lâm nghiệp hay Vào rừng! ~ Chuyện vặt mỗi ngày...        2014
# 1  Ngày 1 tháng 1 năm 1962, một phần của Herøy tr...       Herøy
# 2  Sau hai cuộc chiến tranh Balkan vào năm 1912 v...  vương quốc
# 3  Nguỵ lược () là một sử liệu Trung Quốc do Ngư ...      cổ đại
# 4  Phần phía trước của tàu vũ trụ có chứa một thi...        nhất
#
#                                             metadata
# 0  {'num_sents': 6, 'target_word': {'appeared_in_...
# 1  {'num_sents': 3, 'target_word': {'appeared_in_...
# 2  {'num_sents': 5, 'target_word': {'appeared_in_...
# 3  {'num_sents': 3, 'target_word': {'appeared_in_...
# 4  {'num_sents': 11, 'target_word': {'appeared_in...

# %%
df_lambada_val.head(5)
# Out:
#                                                 text  \
# 0  Tại UEFA Nations League 2020-21, do UEFA sửa đ...
# 1  Ngày 17 tháng 9 năm 1939, sức kháng cự của Ba ...
# 2  Y Lê (Ili) là tên gọi một vùng đất xung quanh ...
# 3  Đến tháng 4 năm 1512, Lê Hy, Trịnh Hưng, Lê Mi...
# 4  Hầu hết các nhà sử học hiện đại không sử dụng ...
#
#                                              context     target_word  \
# 0  Tại UEFA Nations League 2020-21, do UEFA sửa đ...  Nations League
# 1  Ngày 17 tháng 9 năm 1939, sức kháng cự của Ba ...             máu
# 2  Y Lê (Ili) là tên gọi một vùng đất xung quanh ...             nơi
# 3  Đến tháng 4 năm 1512, Lê Hy, Trịnh Hưng, Lê Mi...            giặc
# 4  Hầu hết các nhà sử học hiện đại không sử dụng ...              ít
#
#                                             metadata
# 0  {'num_sents': 10, 'target_word': {'appeared_in...
# 1  {'num_sents': 4, 'target_word': {'appeared_in_...
# 2  {'num_sents': 12, 'target_word': {'appeared_in...
# 3  {'num_sents': 4, 'target_word': {'appeared_in_...
# 4  {'num_sents': 7, 'target_word': {'appeared_in_...

# %% [markdown]
# # vlsp-2023-vllm/wikipediaqa_vi

# %%
import pandas as pd

df_wiki_qa_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/wikipediaqa_vi/data/test-00000-of-00001-87b0058c89924d90.parquet")

# %%
df_wiki_qa_test.head(5)
# Out:
#                                             question  \
# 0  Hai ca sĩ nào đã song ca với nhau trong ca khú...
# 1    Quá liều thuốc có thể dẫn đến những hậu quả gì?
# 2     Toà án Công lý Quốc tế có trụ sở tại nước nào?
# 3  Dushanbe là thủ đô của Tajikistan. Tên gọi lấy...
# 4  Chính phủ Pháp cử tướng Nava sang Đông Dương đ...
#
#                                              choices answerKey  \
# 0  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Bri...         A
# 1  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Ngộ...         C
# 2  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Thụ...         D
# 3  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Thứ...         D
# 4  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Chỉ...         C
#
#           metadata
# 0  ai_la_trieu_phu
# 1           health
# 2  ai_la_trieu_phu
# 3  ai_la_trieu_phu
# 4           people

# %% [markdown]
# # vlsp-2023-vllm/exams_vi

# %%
import pandas as pd

df_exams_vi_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/exams_vi/data/test-00000-of-00001-42f8c598c597c3c1.parquet")

# %%
df_exams_vi_test.head(5)
# Out:
#                                             question  \
# 0  Biển Đông mang lại nguồn nhiệt ẩm dồi dào, lượ...
# 1  Khó khăn lớn nhất về mặt tự nhiên đối với việc...
# 2  Ý nghĩa chủ yếu của việc tăng cường chuyên môn...
# 3  Hướng phát triển chủ đạo của ngành bưu chính t...
# 4  Đất ở đâu trai hiền gái lịch\nNon xanh nước bi...
#
#                                  id  \
# 0  64249f34d6787ebbb4dc2f14e81a23a0
# 1  b10230c9d382c2d12a671c51f562b0db
# 2  1b2009ae23fa39ccb5e4c59d6429e388
# 3  ef5e864a375b0cfa534da08e2fca6eec
# 4  a0960f186d97d94ff6072af47e09232e
#
#                                              choices answerKey  \
# 0  {'label': ['A', 'B', 'C', 'D'], 'text': ['Có t...         C
# 1  {'label': ['A', 'B', 'C', 'D'], 'text': ['đất ...         B
# 2  {'label': ['A', 'B', 'C', 'D'], 'text': ['tạo ...         D
# 3  {'label': ['A', 'B', 'C', 'D'], 'text': ['đẩy ...         B
# 4  {'label': ['A', 'B', 'C', 'D'], 'text': ['Cần ...         D
#
#                                     metadata
# 0  {'grade': 'Lớp 12', 'subject': 'MÔN ĐỊA'}
# 1  {'grade': 'Lớp 12', 'subject': 'MÔN ĐỊA'}
# 2  {'grade': 'Lớp 12', 'subject': 'MÔN ĐỊA'}
# 3  {'grade': 'Lớp 12', 'subject': 'MÔN ĐỊA'}
# 4  {'grade': 'Lớp 12', 'subject': 'MÔN ĐỊA'}

# %% [markdown]
# # vlsp-2023-vllm/comprehension

# %%
import pandas as pd

df_comprehension_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/comprehension/data/test-00000-of-00001-192ecf7907721b26.parquet")
# Out:
# 'The read operation timed out' thrown while requesting GET https://huggingface.co/datasets/vlsp-2023-vllm/comprehension/resolve/main/data/test-00000-of-00001-192ecf7907721b26.parquet
# Retrying in 1s [Retry 1/5].

# %%
df_comprehension_test.head(5)
