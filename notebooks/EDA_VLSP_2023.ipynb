# %% [markdown]
# # vlsp-2023-vllm/lambada_vi

# %%
import pandas as pd

splits = {'test': 'data/test-00000-of-00001-0f570d0544259679.parquet', 'validation': 'data/validation-00000-of-00001-07192d6d50b20f30.parquet'}
df_lambada_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/lambada_vi/" + splits["test"])
df_lambada_val = pd.read_parquet("hf://datasets/vlsp-2023-vllm/lambada_vi/" + splits["validation"])

# %%
# Show full text in every cell
pd.set_option('display.max_colwidth', None)

# Optional: Show all columns and rows without truncation
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_lambada_test.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          text  \
# ...

# %%
df_lambada_val.head(1)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# # vlsp-2023-vllm/wikipediaqa_vi

# %%
import pandas as pd

df_wiki_qa_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/wikipediaqa_vi/data/test-00000-of-00001-87b0058c89924d90.parquet")

# %%
df_wiki_qa_test.head(5)
# Out:
#                                                                                question  \
# 0               Hai ca sĩ nào đã song ca với nhau trong ca khúc “Me against the music”?
# 1                                       Quá liều thuốc có thể dẫn đến những hậu quả gì?
# 2                                        Toà án Công lý Quốc tế có trụ sở tại nước nào?
# 3  Dushanbe là thủ đô của Tajikistan. Tên gọi lấy từ một từ tiếng Ba Tư có nghĩa là gì?
# 4                    Chính phủ Pháp cử tướng Nava sang Đông Dương đảm nhiệm chức vụ gì?
#
#                                                                                                                                                                                          choices  \
# 0                                  {'labels': ['A', 'B', 'C', 'D'], 'text': ['Britney và Madonna', 'Britney và Christina aguilera', 'Christina aguilera và Madonna', 'Britney và Taylor Swift']}
# ...

# %% [markdown]
# # vlsp-2023-vllm/exams_vi

# %%
import pandas as pd

df_exams_vi_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/exams_vi/data/test-00000-of-00001-42f8c598c597c3c1.parquet")

# %%
df_exams_vi_test.head(5)
# Out:
#                                                                                                                                               question  \
# 0                                            Biển Đông mang lại nguồn nhiệt ẩm dồi dào, lượng mưa lớn cho nước ta chủ yếu do biển Đông có đặc điểm gì?
# 1                                                   Khó khăn lớn nhất về mặt tự nhiên đối với việc phát triển kinh tế - xã hội của vùng đồi núi là gì?
# 2                                                             Ý nghĩa chủ yếu của việc tăng cường chuyên môn hóa sản xuất nông nghiệp ở nước ta là gì?
# 3                                                                              Hướng phát triển chủ đạo của ngành bưu chính trong thời gian tới là gì?
# 4  Đất ở đâu trai hiền gái lịch\nNon xanh nước biếc, điện ngọc đền rồng\nTháp bảy tầng, Thánh miếu, chùa Ông\nChuông khua Diệu Đế, trông rung Tam Tòa?
#
#                                  id  \
# ...

# %% [markdown]
# # vlsp-2023-vllm/comprehension

# %%
import pandas as pd

df_comprehension_test = pd.read_parquet("hf://datasets/vlsp-2023-vllm/comprehension/data/test-00000-of-00001-192ecf7907721b26.parquet")

# %%
df_comprehension_test.head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
